# %%
with open('input.txt', 'r') as file:
    data = file.readlines()

# %%
headings = []    
number_lines = {}
for item in data:
    number_line = []
    item = item.strip()
    if item.__len__() < 2:
        continue
    if item[0].isdigit():
        number_line = [item.split(':')[0].split()]
        if headings[-1] in number_lines:
            number_lines[headings[-1]].append(number_line)
            if item.find(':') == -1:
                continue
            else:
                number_lines[headings[-1]] = [item.split(':')[1].split()]
    else:
        headings.append(item.split(':')[0])
        number_line = [item.split(':')[0].split()]
        number_lines[headings[-1]] = [item.split(':')[1].split()]
        
    if number_line:
        pass
    else:
        a = 4

# %%
number_lines
# Out:
# {'seeds': [['3640772818',
#    '104094365',
#    '1236480411',
#    '161072229',
#    '376099792',
#    '370219099',
#    '1590268366',
#    '273715765',
#    '3224333694',
#    '68979978',
#    '2070154278',
#    '189826014',
#    '3855332650',
#    '230434913',
#    '3033760782',
#    '82305885',
#    '837883389',
#    '177854788',
#    '2442602612',
#    '571881366']],
#  'seed-to-soil map': [[],
#   [['496269031', '1203272644', '52136246']],
#   [['548405277', '496269031', '457095898']],
#   [['1005501175', '953364929', '249907715']]],
#  'soil-to-fertilizer map': [[],
#   [['217408321', '2086205436', '25053699']],
#   [['2604208456', '1670861921', '31003781']],
#   [['1631572552', '0', '258383552']],
#   [['129225554', '3768288787', '36192668']],
#   [['2421205388', '2905533654', '126666762']],
#   [['242462020', '3399542287', '357404885']],
#   [['866152503', '3032200416', '253960559']],
#   [['2039921781', '2262442546', '381283607']],
# ...

# %%
    
def printn(strn: str or list) -> None:
    with open('output.txt', 'a') as file:
        if type(strn) == list:
            for i in strn:
                if type(i) == list:
                    file.write(', '.join(i) + '\n')
                    print(i)
                    continue
                else:
                    file.write(i)
                    print(i)
            return
        else:
            print(type(strn), 'typetype')
            file.write(strn + '\n')
            print(strn + '\n')
    
        
    


for key, value in number_lines.items():
    printn(f'key = {key}')
    for i in value:
        printn(i)
    printn('='*40)
# Out:
# <class 'str'> typetype
# key = seeds
#
# 3640772818
# 104094365
# 1236480411
# 161072229
# 376099792
# 370219099
# 1590268366
# 273715765
# 3224333694
# 68979978
# 2070154278
# 189826014
# 3855332650
# 230434913
# 3033760782
# 82305885
# 837883389
# 177854788
# 2442602612
# 571881366
# <class 'str'> typetype
# ...
#
# <class 'str'> typetype
# key = seed-to-soil map
#
# ['496269031', '1203272644', '52136246']
# ['548405277', '496269031', '457095898']
# ['1005501175', '953364929', '249907715']
# <class 'str'> typetype
# ...
#
# <class 'str'> typetype
# key = soil-to-fertilizer map
#
# ['217408321', '2086205436', '25053699']
# ['2604208456', '1670861921', '31003781']
# ['1631572552', '0', '258383552']
# ['129225554', '3768288787', '36192668']
# ['2421205388', '2905533654', '126666762']
# ['242462020', '3399542287', '357404885']
# ['866152503', '3032200416', '253960559']
# ['2039921781', '2262442546', '381283607']
# ['2635212237', '2714844607', '190689047']
# ...

# %%
for head in headings:
    print(head)
    print(number_lines[head])
# Out:
# seeds
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\code\Advent\Advent_2023\day5\problem1.ipynb Cell 3 line 3
#       <a href='vscode-notebook-cell:/c%3A/code/Advent/Advent_2023/day5/problem1.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> for head in headings:
#       <a href='vscode-notebook-cell:/c%3A/code/Advent/Advent_2023/day5/problem1.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a>     print(head)
# ----> <a href='vscode-notebook-cell:/c%3A/code/Advent/Advent_2023/day5/problem1.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a>     print(number_lines[head])
#
# KeyError: 'seeds'

# %%
headings = []

numbers = {}


current_heading = ""

for idx in data:
    #print(idx)
    this = idx.split()
    if this == [] or this == "" or this ==  "\n":
        continue
    for item in this:
        print(item)
        if item == "" or item == "\n":
            continue
        if item.isdigit():
            heading = current_heading
            if heading not in headings:
                headings.append(heading)
            current_heading = ""
            
            #print('is digit')
            if heading in numbers:
                numbers[heading] += item
            elif heading not in numbers and heading != "":
                numbers[heading] = [item]
        else:
            #print('is not digit')
            if item == "":
                continue
            current_heading += item.replace(':', '').strip() 
            #print(f"{current_heading} is current heading")
        #print('')

# %%
headings
# Out:
# ['seeds',
#  '',
#  'seed-to-soilmap',
#  'soil-to-fertilizermap',
#  'fertilizer-to-watermap',
#  'water-to-lightmap',
#  'light-to-temperaturemap',
#  'temperature-to-humiditymap',
#  'humidity-to-locationmap']

# %%
seeds
# Out:
# ['3640772818',
#  '104094365',
#  '1236480411',
#  '161072229',
#  '376099792',
#  '370219099',
#  '1590268366',
#  '273715765',
#  '3224333694',
#  '68979978',
#  '2070154278',
#  '189826014',
#  '3855332650',
#  '230434913',
#  '3033760782',
#  '82305885',
#  '837883389',
#  '177854788',
#  '2442602612',
#  '571881366']
